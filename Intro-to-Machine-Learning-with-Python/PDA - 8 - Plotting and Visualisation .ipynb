# %%
import pandas as pd
import sklearn 
import scipy
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(np.arange(10))

# %% [markdown]
# # Figures and subplots

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2, 2, 3)
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'g--') # why different format than other two?
_ = ax1.hist(randn(100), bins=20, color='y',alpha =0.3) # why this _ ?
ax2.scatter(np.arange(30), np.arange(30)+ 3*randn(30))

# %%
fig, axes = plt.subplots(2,3)

# %% [markdown]
# ## Adjusting the spacing around subplots

# %% [raw]
# subplots_adjust(left = None, bottom= None, right = None, top = None, wspace = None, hspace = None)

# %%
fig, axes = plt.subplots(2,2, sharex = True, sharey = True)
for i in range(2): 
    for j in range(2):
        axes[i, j].hist(randn(500), bins = 50, color ='r', alpha=0.5)
plt.subplots_adjust(wspace =0,hspace=0)

# %% [markdown]
#  # Colors, Markers, and Line Styles

# %% [markdown]
# `ax.plot(x,y, 'g--')` or `ax.plot(x,y, linestyle = '--', color = g)`

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
plt.plot(randn(30).cumsum(),color= 'b', marker='o', linestyle = '--')

# %%
data = randn(30).cumsum()
plt.plot(data, 'k--', label = 'Default')
plt.plot(data, 'k-', drawstyle = 'steps-post', label = 'steps-post') 
plt.legend(loc='best')

# %% [markdown]
# # Ticks, Labels, Legends

# %%
plt.xlim([0,10])
# Out:
# (0, 10)

# %% [markdown]
# ## Setting the title, axis labels, ticks, and ticklabels

# %%
fig = plt.figure(); ax= fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())

# %%
fig = plt.figure(); ax= fig.add_subplot(2,1,1)
ax.plot(randn(1000).cumsum())
ticks = ax.set_xticks([0,250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four','five'], rotation = 30, fontsize = 'small')

# %%
fig = plt.figure(); ax= fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())
ticks = ax.set_xticks([0,250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four','five'], rotation = 30, fontsize = 'small')

ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')

# %% [markdown]
# ## Adding legends

# %%
fig = plt.figure(); ax= fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(), 'k', label= 'one')
ax.plot(randn(1000).cumsum(), 'r--', label='two')
ax.plot(randn(1000).cumsum(), 'b.', label='three')
ax.legend(loc='best')

# %% [markdown]
# # Annotations and Drawing on a Subplot

# %% [raw]
# ax.text(x,y, 'Hello World!', family = 'monospace', fontsize=10)

# %% [raw]
# add plot for ch08/spx.csv data

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
rect = plt.Rectangle((0.2, 0.75),0.4,0.15, color='k', alpha = 0.3)
circ = plt.Circle((0.7,0.2),0.15, color='b', alpha = 0.3)
pgon = plt.Polygon([[0.15,0.15],[0.35,0.4],[0.2,0.6]],color ='g',alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon) # why does it need the command add_patch ? we first chreate atch object and then we add it, i assume?

# %% [markdown]
# # Saving Plots to File

# %% [raw]
# plt.savefig('figpath.svg')

# %% [raw]
# plt.savefig('figpath.png', dpi=400, bbox_inches ='tight')

# %%
from io import BytesIO
buffer = BytesIO()
plt.savefig(buffer)
plot_data = buffer.getvalue()

# %% [markdown]
# # matplotlib configuration

# %% [markdown]
# to set the global default figure size to be 10x10

# %%
plt.rc('figure',figsize=(10,10))

# %% [markdown]
# other parameters to customize are 'figure', 'axes', 'xtick', 'ytick', 'grid', 'legend'

# %% [raw]
# font_options = {'family' : 'monospace',
#                 'weight' : 'bold',
#                 'size' : 'small'}
# plt.rc('font',**font_options)

# %% [markdown]
# # Plotting Function in pandas

# %% [markdown]
# ## Line Plots

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0,100,10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0), columns = ['A','B','C','D'], index = np.arange(0,100,10)) #what does the argument of cumsum() indicate?
df.plot()

# %% [markdown]
# ## Bar Plots

# %%
fid, axes = plt.subplots(2,2)
data = pd.Series(np.random.randn(16), index = list('abcdefghijklmnop'))
#data.plot(kind= 'bar', ax=axes[0], color = 'k', alpha = 0.7)
#data.plot(kind='barh',ax=axes[1], color='k', alpha =0.7)

# %%
df = pd.DataFrame(np.random.randn(6,4),index=['one','two','three','four','five','six'],columns=pd.Index(['A','B','C','D']))
df
# Out:
#               A         B         C         D
# one    1.732606 -0.361533  0.708034 -1.702888
# two   -1.057258 -1.229172  1.135463 -0.272830
# three -0.672907 -0.633269 -1.381625 -0.600337
# four  -1.507974 -0.366911  0.333154  0.913294
# five   0.520244 -1.441913  0.504269  1.242341
# six    0.311846  0.416801 -0.618550 -0.294899

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh', stacked= True, alpha = 0.5)

# %% [raw]
# ch08/tips.csv

# %% [markdown]
# ## Histograms and Density Plots

# %%
comp1 = np.random.normal(0,1, size = 200) # N(0,1)
comp2 = np.random.normal(10,2, size = 200) # N(10,4)
values = pd.Series(np.concatenate([comp1,comp2]))
values.hist(bins=100, alpha =0.3, color='b',normed = True, )
values.plot(kind='kde',style = 'mo--')

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# Scatter plots are useful way to visualize the relationship between one-dimensional data series

# %% [raw]
# ch08/macrodata.csv

# %% [markdown]
# # Plotting Maps: Visualizing Haiti Earthquake Crisis Data

# %% [raw]
# ch08/Haiti.csv
